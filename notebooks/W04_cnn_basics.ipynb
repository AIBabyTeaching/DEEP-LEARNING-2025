# %% [markdown]
# # W04 · Convolutional Neural Networks Basics
#
# This notebook is scaffolded for the Deep Learning Course 2025. Replace the placeholder content with the week's material.

# %% [markdown]
# ## Getting Started
# 1. Duplicate `templates/notebook_template.py` using `scripts/new_week.py` for fresh content.
# 2. Update the Objectives section, add experiments, and track logs under `runs/`.
# 3. Commit with clean outputs—`pre-commit` will strip execution results automatically.

# %% [markdown]
# ## Convolutional Layer Example
#
# **Given**
#
# - Input image: $64 	imes 64 	imes 3$ (RGB)
#
# **Conv1**
#
# - 32 filters
# - Filter/kernel size = $3 	imes 3$
# - Stride = 2
# - Padding = valid (no padding)
#
# **Rules**
#
# - Output shape: $$\left\lfloorrac{I_h + 2P - F_h}{S}
# ight
# floor + 1 \;	imes\; \left\lfloorrac{I_w + 2P - F_w}{S}
# ight
# floor + 1 \;	imes\; 	ext{number of filters in this layer}$$
# - Number of parameters: $\left(F_w 	imes F_h 	imes C_{	ext{in}} + 1
# ight) 	imes$ number of filters in this layer
#
# **Solution**
#
# - Output shape: $$\left\lfloorrac{64 - 2(0) - 3}{2}
# ight
# floor + 1 = 31 \quad\Rightarrow\quad 31 	imes 31 	imes 32$$
# - Number of parameters: $(3 	imes 3 	imes 3 + 1) 	imes 32 = 816$
#
# ---
#
# ### Big Example
#
# **Given**
#
# - Input shape: $256 	imes 256 	imes 3$
#
# **Conv1**
#
# - 64 filters
# - Filter shape $3 	imes 3$
# - Stride = 2
# - Padding = 0 (valid)
#
# **Conv2**
#
# - 128 filters
# - Filter shape $3 	imes 3$
# - Stride = 1
# - Padding = same, where $P = rac{F - 1}{2}$
#
# **Max pooling**
#
# - Window $2 	imes 2$
# - Stride = 2
#
# **Conv3**
#
# - 256 filters
# - Filter shape $3 	imes 3$
# - Stride = 1
# - Padding = same
#
# **Flatten & fully connected**
#
# - Flatten output: propagate the previous tensor
# - FC1: 500 neurons
# - FC2: 10 neurons
#
# **Rules**
#
# - Output shape: $$\left\lfloorrac{I_h + 2P - F_h}{S}
# ight
# floor + 1 \;	imes\; \left\lfloorrac{I_w + 2P - F_w}{S}
# ight
# floor + 1 \;	imes\; 	ext{number of filters in layer}$$
# - Number of parameters in a convolutional layer: $\left(F_w 	imes F_h 	imes C_{	ext{in}} + 1
# ight) 	imes$ number of filters in the layer
# - Number of parameters in a fully connected layer: $(	ext{inputs} + 1) 	imes$ number of units
#
# **Solution**
#
# - Conv1 output shape: $\left\lfloorrac{256 - 3}{2}
# ight
# floor + 1 = 127 \Rightarrow 127 	imes 127 	imes 64$
# - Conv1 parameters: $(3 	imes 3 	imes 3 + 1) 	imes 64 = 1{,}792$
# - Conv2 output shape: padding keeps spatial dims $127 	imes 127 	imes 128$
# - Conv2 parameters: $(3 	imes 3 	imes 64 + 1) 	imes 128 = 73{,}856$
# - Max pooling output shape: $\left\lfloorrac{127 - 2}{2}
# ight
# floor + 1 = 63 \Rightarrow 63 	imes 63 	imes 128$
# - Max pooling parameters: none
# - Conv3 output shape: padding keeps spatial dims $63 	imes 63 	imes 256$
# - Conv3 parameters: $(3 	imes 3 	imes 128 + 1) 	imes 256 = 295{,}168$
# - Flatten output shape: $63 	imes 63 	imes 256 = 1{,}016{,}064$ features
# - FC1 parameters: $(1{,}016{,}064 + 1) 	imes 500 = 508{,}032{,}500$
# - FC2 parameters: $(500 + 1) 	imes 10 = 5{,}010$
